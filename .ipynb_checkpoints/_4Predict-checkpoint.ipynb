# %%
import keras
import tensorflow as tf
print('TensorFlow version:', tf.__version__) 
print('Keras version:', keras.__version__)
import sys
import os
from os.path import join
import json
import random
import itertools
import re
import datetime
#import cairocffi as cairo
import editdistance
import numpy as np
from scipy import ndimage
import pylab
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from keras import backend as K
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.layers import Input, Dense, Activation
from keras.layers import Reshape, Lambda
from keras.layers.merge import add, concatenate
from keras.models import Model, load_model
from keras.layers.recurrent import GRU
from keras.optimizers import SGD
from keras.utils.data_utils import get_file
from keras.preprocessing import image
import keras.callbacks
import cv2
# Out:
# Using TensorFlow backend.
# TensorFlow version: 1.8.0
# Keras version: 2.2.2

# %%
sess = tf.Session()
K.set_session(sess)
from keras.models import model_from_json

DEVICE = "/cpu:0"  # /use cpu:0 for cpu only or /gpu:0

# %%
working_dir = os.getcwd()
print("Working directory is:",working_dir)
sys.path.append(working_dir)  # To find local version of the library

#ROOT_DIR = os.path.join("/home/user/Source/Evrim/Turkishplate") #linux
ROOT_DIR = os.path.join("C:/Users/is95217/source/plate/turkishplate") #win
sys.path.append(ROOT_DIR + "/Python")


#DATA_DIR = "/home/user/Source/data/dataEvrim/Original_15Kcrop_distributed"  #linux
DATA_DIR = "C:/Users/is95217/data/Original_15Kcrop_distributed" #win
print("Data:", DATA_DIR)
print("Source code:", ROOT_DIR)
# Out:
# Working directory is: C:\Users\is95217\source\plate\turkishplate
# Data: C:/Users/is95217/data/Original_15Kcrop_distributed
# Source code: C:/Users/is95217/source/plate/turkishplate

# %%
sys.path.append(os.path.dirname(os.path.realpath('PPlate')) + "/python")
import PPlate as p

# %% [markdown]
# # LOAD MODEL

# %%
# load json and create model
#fmodel='lr0.02_mom0.9'
#fmodel = '/Model/Plate15K'

#loaded_model=p.load_model(ROOT_DIR + '/Model/plate15K')
loaded_model=p.load_model(ROOT_DIR + '/Model/model15k_3GRU')

# %% [markdown]
# # Test on validation images

# %%
cnt_test= len(os.listdir(DATA_DIR + '/test'))

tiger_test = p.TextImageGenerator(DATA_DIR, '/test', 128, 64, cnt_test, 4) # batch size 
tiger_test.build_data()

net_inp = loaded_model.get_layer(name='the_input').input
net_out = loaded_model.get_layer(name='softmax').output

# %%
i=0
for inp_value, _ in tiger_test.next_batch():   
    nbr_example = inp_value['the_input'].shape[0]    
    print('the_input:',np.shape(inp_value['the_input']))
    print('the_labels:',np.shape(inp_value['the_labels']))
    print('input_length:',np.shape(inp_value['input_length']))
    print('label_length:',np.shape(inp_value['label_length']))
    if K.image_data_format() == 'channels_first':
        img = inp_value['the_input'][0, 0, :, :]
    else:
        img = inp_value['the_input'][0, :, :, 0]
    
    plt.imshow(img.T, cmap='gray')
    plt.show()
    print('2) the_labels (plate number): %s is encoded as %s' % 
          (p.labels_to_text(inp_value['the_labels'][0]), list(map(int, inp_value['the_labels'][0]))))
    print('3) input_length (width of image that is fed to the loss function): %d == %d / 4 - 2' % 
          (inp_value['input_length'][0], tiger_test.img_w))
    print('4) label_length (length of plate number): %d' % inp_value['label_length'][0])    
    i= i + 1
    if i > 10:
        break
    #for i  in range(nbr_example):
    #    print("labels:", inp_value['the_labels'][i])
# Out:
# the_input: (1565, 128, 64, 1)
# the_labels: (1565, 8)
# input_length: (1565, 1)
# label_length: (1565, 1)
# 2) the_labels (plate number): 34JR3252 is encoded as [3, 4, 19, 26, 3, 2, 5, 2]
# 3) input_length (width of image that is fed to the loss function): 30 == 128 / 4 - 2
# 4) label_length (length of plate number): 8
# the_input: (1565, 128, 64, 1)
# the_labels: (1565, 8)
# input_length: (1565, 1)
# label_length: (1565, 1)
# 2) the_labels (plate number): 41L9883 is encoded as [4, 1, 21, 9, 8, 8, 3, 34]
# 3) input_length (width of image that is fed to the loss function): 30 == 128 / 4 - 2
# 4) label_length (length of plate number): 7
# the_input: (1565, 128, 64, 1)
# the_labels: (1565, 8)
# input_length: (1565, 1)
# label_length: (1565, 1)
# 2) the_labels (plate number): 41TY956 is encoded as [4, 1, 28, 31, 9, 5, 6, 34]
# 3) input_length (width of image that is fed to the loss function): 30 == 128 / 4 - 2
# 4) label_length (length of plate number): 7
# the_input: (1565, 128, 64, 1)
# the_labels: (1565, 8)
# input_length: (1565, 1)
# label_length: (1565, 1)
# 2) the_labels (plate number): 41YV004 is encoded as [4, 1, 31, 30, 0, 0, 4, 34]
# 3) input_length (width of image that is fed to the loss function): 30 == 128 / 4 - 2
# 4) label_length (length of plate number): 7
# the_input: (1565, 128, 64, 1)
# the_labels: (1565, 8)
# input_length: (1565, 1)
# label_length: (1565, 1)
# 2) the_labels (plate number): 01EAS03 is encoded as [0, 1, 14, 10, 27, 0, 3, 34]
# 3) input_length (width of image that is fed to the loss function): 30 == 128 / 4 - 2
# 4) label_length (length of plate number): 7
# the_input: (1565, 128, 64, 1)
# the_labels: (1565, 8)
# input_length: (1565, 1)
# label_length: (1565, 1)
# 2) the_labels (plate number): 41VZ812 is encoded as [4, 1, 30, 32, 8, 1, 2, 34]
# 3) input_length (width of image that is fed to the loss function): 30 == 128 / 4 - 2
# 4) label_length (length of plate number): 7
# the_input: (1565, 128, 64, 1)
# the_labels: (1565, 8)
# input_length: (1565, 1)
# label_length: (1565, 1)
# 2) the_labels (plate number): 34GB2716 is encoded as [3, 4, 16, 11, 2, 7, 1, 6]
# 3) input_length (width of image that is fed to the loss function): 30 == 128 / 4 - 2
# 4) label_length (length of plate number): 8
# the_input: (1565, 128, 64, 1)
# the_labels: (1565, 8)
# input_length: (1565, 1)
# label_length: (1565, 1)
# 2) the_labels (plate number): 41TN410 is encoded as [4, 1, 28, 23, 4, 1, 0, 34]
# 3) input_length (width of image that is fed to the loss function): 30 == 128 / 4 - 2
# 4) label_length (length of plate number): 7
# the_input: (1565, 128, 64, 1)
# the_labels: (1565, 8)
# input_length: (1565, 1)
# label_length: (1565, 1)
# 2) the_labels (plate number): 34DC0665 is encoded as [3, 4, 13, 12, 0, 6, 6, 5]
# 3) input_length (width of image that is fed to the loss function): 30 == 128 / 4 - 2
# 4) label_length (length of plate number): 8
# the_input: (1565, 128, 64, 1)
# the_labels: (1565, 8)
# input_length: (1565, 1)
# label_length: (1565, 1)
# 2) the_labels (plate number): 41YF958 is encoded as [4, 1, 31, 15, 9, 5, 8, 34]
# 3) input_length (width of image that is fed to the loss function): 30 == 128 / 4 - 2
# 4) label_length (length of plate number): 7
# the_input: (1565, 128, 64, 1)
# the_labels: (1565, 8)
# input_length: (1565, 1)
# label_length: (1565, 1)
# 2) the_labels (plate number): 43PL219 is encoded as [4, 3, 25, 21, 2, 1, 9, 34]
# 3) input_length (width of image that is fed to the loss function): 30 == 128 / 4 - 2
# 4) label_length (length of plate number): 7

# %%
"""

cnt_test= 2000#len(os.listdir(DATA_DIR + '/train'))

tiger_test = p.TextImageGenerator(DATA_DIR, '/train', 128, 64, cnt_test, 4) # batch size 
tiger_test.build_data()

net_inp = loaded_model.get_layer(name='the_input').input
net_out = loaded_model.get_layer(name='softmax').output
"""
# Out:
# "\n\ncnt_test= 2000#len(os.listdir(DATA_DIR + '/train'))\n\ntiger_test = p.TextImageGenerator(DATA_DIR, '/train', 128, 64, cnt_test, 4) # batch size \ntiger_test.build_data()\n\nnet_inp = loaded_model.get_layer(name='the_input').input\nnet_out = loaded_model.get_layer(name='softmax').output\n"

# %%
tiger_test.batch_size,tiger_test.img_h,tiger_test.img_w
# Out:
# (1565, 64, 128)

# %% [markdown]
# #  Full test set

# %%
for inp_value, _ in tiger_test.next_batch():
    matched=0
    non_matched=0
    testset_cnt = inp_value['the_input'].shape[0]
    X_data = inp_value['the_input']
    
    net_out_value = sess.run(net_out, feed_dict={net_inp:X_data})
    pred_texts = p.decode_batch(net_out_value)
    
    labels = inp_value['the_labels']
    texts = []     
    
    for label in labels:
        text = p.labels_to_text(label)        
        texts.append(text)       
    
    for cnt in range(testset_cnt):        
        
        if pred_texts[cnt] == texts[cnt]:
            matched += 1            
        else:
            non_matched +=  1
            if len(pred_texts[cnt])<7:
                print('wrong Predicted: %s True: %s i: %s len_pred: %s len_true: %s' % (pred_texts[cnt], texts[cnt],str(cnt),
                                                                              len(pred_texts[cnt]),len(texts[cnt])))
            
    print("matched=",matched, ",total=",testset_cnt , "TP: %", round(matched/testset_cnt, 2) * 100)
    break
# Out:
# wrong Predicted: 34PE11 True: 34ZP411 i: 0 len_pred: 6 len_true: 7
# wrong Predicted: 34FC41 True: 34FBC41 i: 6 len_pred: 6 len_true: 7
# wrong Predicted: 5HPF96 True: 55HPF98 i: 8 len_pred: 6 len_true: 7
# wrong Predicted: 41TF58 True: 41TF588 i: 11 len_pred: 6 len_true: 7
# wrong Predicted: 42CY18 True: 42CLY18 i: 28 len_pred: 6 len_true: 7
# wrong Predicted: 06DD23 True: 06GD2436 i: 33 len_pred: 6 len_true: 8
# wrong Predicted: 4K362 True: 34SB6153 i: 37 len_pred: 5 len_true: 8
# wrong Predicted: 06BT90 True: 06AOT04 i: 41 len_pred: 6 len_true: 7
# wrong Predicted: 06Z81 True: 06ZIZ81 i: 45 len_pred: 5 len_true: 7
# wrong Predicted: 06BC12 True: 06BGC12 i: 57 len_pred: 6 len_true: 7
# wrong Predicted: 41TA16 True: 41TA164 i: 60 len_pred: 6 len_true: 7
# wrong Predicted: 41T114 True: 41YT114 i: 65 len_pred: 6 len_true: 7
# wrong Predicted: 06BAB3 True: 06BEM33 i: 68 len_pred: 6 len_true: 7
# wrong Predicted: 41T150 True: 41TT150 i: 74 len_pred: 6 len_true: 7
# wrong Predicted: 41L152 True: 41L4152 i: 82 len_pred: 6 len_true: 7
# wrong Predicted: 17L86 True: 17LR866 i: 622 len_pred: 5 len_true: 7
# wrong Predicted: 16AR42 True: 16AAR42 i: 626 len_pred: 6 len_true: 7
# wrong Predicted: 06DP95 True: 06DBP95 i: 627 len_pred: 6 len_true: 7
# wrong Predicted: 41TZ75 True: 41R7709 i: 634 len_pred: 6 len_true: 7
# wrong Predicted: 59J295 True: 59VJ295 i: 635 len_pred: 6 len_true: 7
# wrong Predicted: 34NU44 True: 34NTU44 i: 637 len_pred: 6 len_true: 7
# wrong Predicted: 34VJ19 True: 34VAJ19 i: 643 len_pred: 6 len_true: 7
# wrong Predicted: 41K12 True: 41KC122 i: 644 len_pred: 5 len_true: 7
# wrong Predicted: 43B014 True: 43BA014 i: 649 len_pred: 6 len_true: 7
# wrong Predicted: 42CK51 True: 42CCK51 i: 657 len_pred: 6 len_true: 7
# wrong Predicted: 54D672 True: 54D4672 i: 658 len_pred: 6 len_true: 7
# wrong Predicted: 41U004 True: 41U0004 i: 670 len_pred: 6 len_true: 7
# wrong Predicted: 06NT9 True: 06NMT99 i: 674 len_pred: 5 len_true: 7
# wrong Predicted: 41V387 True: 41VD387 i: 684 len_pred: 6 len_true: 7
# wrong Predicted: 41R149 True: 41LR149 i: 718 len_pred: 6 len_true: 7
# wrong Predicted: 1A512 True: 08FR4594 i: 720 len_pred: 5 len_true: 8
# wrong Predicted: 41F602 True: 41R6602 i: 725 len_pred: 6 len_true: 7
# wrong Predicted: 0F649 True: 80FZ649 i: 730 len_pred: 5 len_true: 7
# wrong Predicted: 41T150 True: 41TT150 i: 746 len_pred: 6 len_true: 7
# wrong Predicted: 41H333 True: 41H3233 i: 747 len_pred: 6 len_true: 7
# wrong Predicted: 41AC65 True: 41AAC665 i: 749 len_pred: 6 len_true: 8
# wrong Predicted: 16HK56 True: 16MBK56 i: 753 len_pred: 6 len_true: 7
# wrong Predicted: 41U710 True: 41PU710 i: 763 len_pred: 6 len_true: 7
# wrong Predicted: 41R660 True: 41G6602 i: 768 len_pred: 6 len_true: 7
# wrong Predicted: 2LF676 True: 42LF676 i: 770 len_pred: 6 len_true: 7
# wrong Predicted: 43A420 True: 43AN420 i: 792 len_pred: 6 len_true: 7
# wrong Predicted: 05DG25 True: 05DG256 i: 798 len_pred: 6 len_true: 7
# wrong Predicted: 42DPE8 True: 42DPE81 i: 858 len_pred: 6 len_true: 7
# wrong Predicted: 41UF3 True: 41D73431 i: 885 len_pred: 5 len_true: 8
# wrong Predicted: 41B082 True: 41B0807 i: 891 len_pred: 6 len_true: 7
# wrong Predicted: 8EZ92 True: 68EZ929 i: 899 len_pred: 5 len_true: 7
# wrong Predicted: 5V215 True: 55VJ215 i: 900 len_pred: 5 len_true: 7
# wrong Predicted: 41UN30 True: 41UM304 i: 904 len_pred: 6 len_true: 7
# wrong Predicted: 35HP96 True: 35HPF98 i: 913 len_pred: 6 len_true: 7
# wrong Predicted: 41E152 True: 41YE152 i: 918 len_pred: 6 len_true: 7
# wrong Predicted: 34PK86 True: 34PN861 i: 919 len_pred: 6 len_true: 7
# wrong Predicted: 42DA69 True: 42DAG69 i: 931 len_pred: 6 len_true: 7
# wrong Predicted: 41BB13 True: 41VP133 i: 951 len_pred: 6 len_true: 7
# wrong Predicted: 5K0065 True: 55K0765 i: 961 len_pred: 6 len_true: 7
# wrong Predicted: 41KC55 True: 41KC563 i: 973 len_pred: 6 len_true: 7
# wrong Predicted: 33EA54 True: 37EA541 i: 975 len_pred: 6 len_true: 7
# wrong Predicted: 41V156 True: 41V1751 i: 983 len_pred: 6 len_true: 7
# wrong Predicted: 06JS56 True: 06JSZ56 i: 1016 len_pred: 6 len_true: 7
# wrong Predicted: 1AY096 True: 11AY096 i: 1022 len_pred: 6 len_true: 7
# wrong Predicted: 41U706 True: 41UU706 i: 1032 len_pred: 6 len_true: 7
# wrong Predicted: 41N507 True: 41NZ507 i: 1036 len_pred: 6 len_true: 7
# wrong Predicted: 41U004 True: 41U0004 i: 1047 len_pred: 6 len_true: 7
# wrong Predicted: 41V116 True: 41V1166 i: 1048 len_pred: 6 len_true: 7
# wrong Predicted: 41R44 True: 41R4644 i: 1049 len_pred: 5 len_true: 7
# wrong Predicted: 41U084 True: 41UL084 i: 1052 len_pred: 6 len_true: 7
# wrong Predicted: 34HZ14 True: 34HC1114 i: 1053 len_pred: 6 len_true: 8
# wrong Predicted: 26PN62 True: 26PN623 i: 1067 len_pred: 6 len_true: 7
# wrong Predicted: 41D756 True: 41D7456 i: 1071 len_pred: 6 len_true: 7
# wrong Predicted: 42A51 True: 42ANA51 i: 1076 len_pred: 5 len_true: 7
# wrong Predicted: 34V904 True: 34VV9904 i: 1091 len_pred: 6 len_true: 8
# wrong Predicted: 41Y568 True: 41YT568 i: 1092 len_pred: 6 len_true: 7
# wrong Predicted: 41Y10 True: 41TV110 i: 1097 len_pred: 5 len_true: 7
# wrong Predicted: 41D196 True: 41D1986 i: 1101 len_pred: 6 len_true: 7
# wrong Predicted: 35R408 True: 35ZR408 i: 1110 len_pred: 6 len_true: 7
# wrong Predicted: 47R428 True: 47PZ425 i: 1111 len_pred: 6 len_true: 7
# wrong Predicted: 34V904 True: 34VV9904 i: 1112 len_pred: 6 len_true: 8
# wrong Predicted: 7AS21 True: 27ASR21 i: 1113 len_pred: 5 len_true: 7
# wrong Predicted: 06AZ19 True: 06NAZ09 i: 1122 len_pred: 6 len_true: 7
# wrong Predicted: 41B540 True: 41VB540 i: 1129 len_pred: 6 len_true: 7
# wrong Predicted: 41U708 True: 41UU706 i: 1134 len_pred: 6 len_true: 7
# wrong Predicted: 06SD40 True: 06SDA48 i: 1139 len_pred: 6 len_true: 7
# wrong Predicted: 41L21 True: 41L2021 i: 1161 len_pred: 5 len_true: 7
# wrong Predicted: 06JUR3 True: 06JUR33 i: 1164 len_pred: 6 len_true: 7
# wrong Predicted: 41U205 True: 41UD205 i: 1168 len_pred: 6 len_true: 7
# wrong Predicted: 41UB70 True: 41UB706 i: 1172 len_pred: 6 len_true: 7
# wrong Predicted: 41D453 True: 41DR453 i: 1173 len_pred: 6 len_true: 7
# wrong Predicted: 41R634 True: 41RF634 i: 1180 len_pred: 6 len_true: 7
# wrong Predicted: 34UV83 True: 34UV8373 i: 1193 len_pred: 6 len_true: 8
# wrong Predicted: 10Y395 True: 10Y3965 i: 1197 len_pred: 6 len_true: 7
# wrong Predicted: 06BIE1 True: 06BHE11 i: 1204 len_pred: 6 len_true: 7
# wrong Predicted: 08ED73 True: 08ED723 i: 1207 len_pred: 6 len_true: 7
# wrong Predicted: 35MEG2 True: 35MEG27 i: 1215 len_pred: 6 len_true: 7
# wrong Predicted: 34LS71 True: 34LCS71 i: 1227 len_pred: 6 len_true: 7
# wrong Predicted: 55AL24 True: 55ASL24 i: 1230 len_pred: 6 len_true: 7
# wrong Predicted: 16BY11 True: 16BLY11 i: 1260 len_pred: 6 len_true: 7
# wrong Predicted: 43B014 True: 43BA014 i: 1272 len_pred: 6 len_true: 7
# wrong Predicted: 59F824 True: 59FF824 i: 1281 len_pred: 6 len_true: 7
# wrong Predicted: 43DD33 True: 43DD3338 i: 1317 len_pred: 6 len_true: 8
# wrong Predicted: 28BK97 True: 78BK977 i: 1329 len_pred: 6 len_true: 7
# wrong Predicted: 35A489 True: 35AAJ48 i: 1334 len_pred: 6 len_true: 7
# wrong Predicted: 43PN75 True: 43PN757 i: 1348 len_pred: 6 len_true: 7
# wrong Predicted: 41R653 True: 41R6584 i: 1349 len_pred: 6 len_true: 7
# wrong Predicted: 34V438 True: 34HV4755 i: 1364 len_pred: 6 len_true: 8
# wrong Predicted: 06BF54 True: 06BFA54 i: 1367 len_pred: 6 len_true: 7
# wrong Predicted: 42DY18 True: 42CLY18 i: 1377 len_pred: 6 len_true: 7
# wrong Predicted: 43HP98 True: 43HP989 i: 1382 len_pred: 6 len_true: 7
# wrong Predicted: 59AB61 True: 59AB661 i: 1383 len_pred: 6 len_true: 7
# wrong Predicted: 06JU11 True: 06JUD11 i: 1387 len_pred: 6 len_true: 7
# wrong Predicted: 06DF36 True: 16FDP36 i: 1394 len_pred: 6 len_true: 7
# wrong Predicted: 51A832 True: 50KF835 i: 1397 len_pred: 6 len_true: 7
# wrong Predicted: 41V116 True: 41V1166 i: 1398 len_pred: 6 len_true: 7
# wrong Predicted: 42SM3 True: 42CSA31 i: 1414 len_pred: 5 len_true: 7
# wrong Predicted: 41PN42 True: 41PN428 i: 1434 len_pred: 6 len_true: 7
# wrong Predicted: 33CV6 True: 33CMH60 i: 1448 len_pred: 5 len_true: 7
# wrong Predicted: 35MN34 True: 35MND34 i: 1450 len_pred: 6 len_true: 7
# wrong Predicted: 31AL63 True: 31AOL83 i: 1464 len_pred: 6 len_true: 7
# wrong Predicted: 61K223 True: 61K2233 i: 1478 len_pred: 6 len_true: 7
# wrong Predicted: 33B863 True: 33NB863 i: 1479 len_pred: 6 len_true: 7
# wrong Predicted: 8BK438 True: 78BK438 i: 1480 len_pred: 6 len_true: 7
# wrong Predicted: 34BG08 True: 34BGT068 i: 1497 len_pred: 6 len_true: 8
# wrong Predicted: 31L84 True: 41L8447 i: 1526 len_pred: 5 len_true: 7
# wrong Predicted: 43U497 True: 43U4972 i: 1537 len_pred: 6 len_true: 7
# wrong Predicted: 41VN81 True: 41VN8111 i: 1561 len_pred: 6 len_true: 8
# matched= 966 ,total= 1565 TP: % 62.0

# %%
#matched= 1071 ,total= 1568 TP: % 68.0  25 epoch 15k  test accuracy
#matched= 1082 ,total= 1567 TP: % 69.0 epoch 15k  val accuracy
#matched= 1380 ,total= 2000 TP: % 69.0 train accuracy
