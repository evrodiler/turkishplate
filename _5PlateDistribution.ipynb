# %%
import pandas as pd
import sys
import os
import seaborn as sns

# %%
working_dir = os.getcwd()
print("Working directory is:",working_dir)
# Out:
# Working directory is: C:\Users\is95217\source\turkishplate

# %%
win=1
if win:
    ROOT_DIR = os.path.join("C:/Users/is95217/source/turkishplate") 
    DATA_DIR = "C:/Users/is95217/data/Original_15Kcrop_distributed"  #win
else:    
    ROOT_DIR = os.path.join("/home/user/Source/Evrim/Turkishplate")
    DATA_DIR = "/home/user/Source/data/dataEvrim/Original_15Kcrop_distributed"  #linux
sys.path.append(ROOT_DIR + "/Python")


print("Data:", DATA_DIR)
print("Source code:", ROOT_DIR)
# Out:
# Data: C:/Users/is95217/data/Original_15Kcrop_distributed
# Source code: C:/Users/is95217/source/turkishplate

# %%
kac_adet= 20 #kac adet plaka grubu gösterilsin?

import Modelop as m
import Plot as p
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # prepare predictions

# %%
#prep for predictions  ************
import keras
import tensorflow as tf
import sys
import os
from keras import backend as K
import itertools

sess = tf.Session()
K.set_session(sess)

#load model 
loaded_model=m.load_model(ROOT_DIR + '/Model/lr0.02_mom0.9')

# %%
#prepare test data for prediction
test_dirpath = DATA_DIR + '/test'
test_cnt=len(os.listdir(test_dirpath))

tiger_test = m.TextImageGenerator(DATA_DIR, 'test', 128, 64, test_cnt , 4) 
tiger_test.build_data()
net_inp = loaded_model.get_layer(name='the_input').input
net_out = loaded_model.get_layer(name='softmax').output

#predict and put all non_matched& matched plates in to lists
nmatch_str,match_str,nmatched,matched =m.all_plates_classify(sess,tiger_test,net_inp,net_out)

# dataset creation for predictions
df2= p.datacreate('',False,nmatch_str)   #2nd param path_true,3rd param takes list
print("dataset ready for test predictions")
# Out:
# hata!  1#41LF48#02062018#084238.jpgnolu plakanın etiketi6uzunlukta!
# dataset ready for test predictions

# %%
import numpy as np
np.shape(nmatch_str)
# Out:
# (391,)

# %%
nmatch_str
# Out:
# ['01BH907',
#  '01BH907',
#  '01BH907',
#  '01DEV25',
#  '01DHF81',
#  '01EJJ70',
#  '03RH012',
#  '04BY6066',
#  '05DH466',
#  '06ANG42',
#  '06BAF34',
#  '06BBT23',
#  '06BEH27',
#  '06BFA54',
#  '06BFV30',
#  '06BHB17',
#  '06BHC75',
#  '06BID70',
#  '06BID80',
#  '06BY6060',
#  '06BY6064',
#  '06BY6066',
#  '06BY6068',
#  '06BY6074',
#  '06DK5303',
#  '06DK5306',
#  '06DK5306',
#  '06DK5906',
#  '06DL7323',
#  '06EG2996',
#  '06ET8477',
#  '06FG5961',
#  '06HZE17',
#  '06KA1780',
#  '06NJN64',
#  '06UAF34',
#  '09DV874',
#  '10Y0423',
#  '10Y0676',
#  '10Y0676',
#  '10Y2258',
#  '10Y2258',
#  '10Y3965',
#  '10Y5842',
#  '10Y5869',
#  '10Y5869',
#  '10Y6152',
#  '11RC010',
#  '14DD215',
#  '14DV571',
#  '14KL495',
#  '16FDP36',
#  '16HCL98',
#  '16SJR02',
#  '18DF787',
#  '18DT491',
#  '19EP169',
#  '20AZM05',
#  '23FU400',
#  '23HV358',
#  '26NC812',
#  '27SZ010',
#  '27VG489',
#  '29DC397',
#  '31AVA56',
#  '31R0341',
#  '33BDJ20',
#  '33BDK51',
#  '33BDK513',
#  '33CTT35',
#  '33CYA90',
#  '33EJN96',
#  '34ABA890',
#  '34AD1602',
#  '34AD8048',
#  '34AD8050',
#  '34AG2504',
#  '34AIA395',
#  '34AIA980',
#  '34AIA980',
#  '34AIA981',
#  '34AIA988',
#  '34AIP268',
#  '34AIP268',
#  '34ALC79',
#  '34AR9366',
#  '34AT8833',
#  '34AU7696',
#  '34AU7696',
#  '34AZ5258',
#  '34BC9857',
#  '34BDJ884',
#  '34BEP732',
#  '34BGS893',
#  '34BK1532',
#  '34BK9835',
#  '34BM8341',
#  '34BMU22',
#  '34BT1890',
#  '34BT3390',
#  '34BT3390',
#  '34CAB60',
#  '34CCV17',
#  '34CKM09',
#  '34DB6330',
#  '34DD6546',
#  '34DD6589',
#  '34DG7064',
#  '34DU0965',
#  '34DY7017',
#  '34DZ4238',
#  '34DZ4956',
#  '34DZ4957',
#  '34EC6516',
#  '34EC6517',
#  '34EJ4124',
#  '34EJ7239',
#  '34EL4820',
#  '34EM1620',
#  '34EN1892',
#  '34ER5782',
#  '34ET8013',
#  '34FB9902',
#  '34FS3726',
#  '34FV9497',
#  '34GA1885',
#  '34GB2716',
#  '34GB842',
#  '34GB8423',
#  '34GB8423',
#  '34GB8423',
#  '34GF2802',
#  '34GF7661',
#  '34GF7661',
#  '34GF7661',
#  '34GF796',
#  '34GH6401',
#  '34GJ259',
#  '34GJ259',
#  '34GK7637',
#  '34GL1613',
#  '34GL1613',
#  '34GL1613',
#  '34GM7284',
#  '34GPJ76',
#  '34GT4589',
#  '34GT6613',
#  '34GV0096',
#  '34GV8937',
#  '34GV8974',
#  '34GV9172',
#  '34GVY89',
#  '34GZ7806',
#  '34HAZ84',
#  '34HG9494',
#  '34HG9494',
#  '34HJ1187',
#  '34HJ4907',
#  '34HJ6238',
#  '34HK7861',
#  '34HL420',
#  '34HP5200',
#  '34HU0686',
#  '34HY4262',
#  '34HZ1463',
#  '34HZZ48',
#  '34HZZ48',
#  '34JC5014',
#  '34JC8676',
#  '34JC8691',
#  '34JC9911',
#  '34JS0030',
#  '34JT3999',
#  '34KAR76',
#  '34KAR76',
#  '34KM7109',
#  '34KM7118',
#  '34KM7134',
#  '34KM7134',
#  '34KM7134',
#  '34KT4894',
#  '34KZ6107',
#  '34LB5443',
#  '34LC6158',
#  '34LOG71',
#  '34MEP49',
#  '34NL6405',
#  '34NTU44',
#  '34NTU44',
#  '34NUY85',
#  '34NUY85',
#  '34NV5605',
#  '34PG513',
#  '34PJ922',
#  '34PK7533',
#  '34PK7533',
#  '34PM7858',
#  '34PS5891',
#  '34SMJ10',
#  '34SMJ10',
#  '34SOT34',
#  '34SYP14',
#  '34TJ1269',
#  '34TJ1269',
#  '34TK6569',
#  '34TM1981',
#  '34TM1981',
#  '34TM9544',
#  '34TN1268',
#  '34TP5904',
#  '34TU9742',
#  '34TV6476',
#  '34TZ8894',
#  '34UF1364',
#  '34UJ8861',
#  '34UM5680',
#  '34UZV72',
#  '34VR1529',
#  '34VT5433',
#  '34YTF78',
#  '34ZK4798',
#  '34ZK4798',
#  '34ZK7516',
#  '34ZP2058',
#  '34ZP6208',
#  '35AU730',
#  '35EH612',
#  '35FHK28',
#  '35HB1746',
#  '35HPF96',
#  '35HPF96',
#  '35JJ0886',
#  '35MEG27',
#  '35MGL63',
#  '35MGL71',
#  '35MGV05',
#  '35MGV05',
#  '35MSL98',
#  '35MSM85',
#  '35MSN18',
#  '35MTM42',
#  '35V8413',
#  '41A5440',
#  '41AAD42',
#  '41AAE791',
#  '41AL520',
#  '41AN968',
#  '41AR412',
#  '41AR907',
#  '41B0530',
#  '41B0807',
#  '41B1769',
#  '41B3506',
#  '41B5789',
#  '41B5803',
#  '41BH163',
#  '41BU069',
#  '41BY304',
#  '41EE027',
#  '41FH372',
#  '41FL404',
#  '41FL404',
#  '41G6602',
#  '41GP974',
#  '41HK754',
#  '41HM358',
#  '41L1232',
#  '41L3107',
#  '41LD850',
#  '41LV232',
#  '41MB019',
#  '41NU934',
#  '41NU934',
#  '41NV629',
#  '41PE731',
#  '41R2285',
#  '41R4178',
#  '41R4250',
#  '41R5975',
#  '41R7706',
#  '41R8493',
#  '41R8715',
#  '41RK029',
#  '41T0077',
#  '41TB738',
#  '41TD238',
#  '41TK804',
#  '41TL424',
#  '41TM882',
#  '41TM886',
#  '41TU869',
#  '41TV110',
#  '41TY849',
#  '41TY849',
#  '41TY960',
#  '41U1892',
#  '41U2238',
#  '41U2439',
#  '41U7900',
#  '41UF797',
#  '41UF877',
#  '41UH004',
#  '41UH228',
#  '41UJ077',
#  '41UJ356',
#  '41UM038',
#  '41UM038',
#  '41UR315',
#  '41US614',
#  '41UU104',
#  '41UU485',
#  '41V0299',
#  '41V0630',
#  '41V1152',
#  '41V1152',
#  '41VB004',
#  '41VB618',
#  '41VC105',
#  '41VD358',
#  '41VD617',
#  '41VE104',
#  '41VE889',
#  '41VF892',
#  '41VF892',
#  '41VG124',
#  '41VL637',
#  '41VM059',
#  '41VN004',
#  '41VN259',
#  '41VN690',
#  '41VN802',
#  '41VN802',
#  '41VN807',
#  '41VP004',
#  '41VP004',
#  '41VP934',
#  '41VS984',
#  '41VV576',
#  '41VY814',
#  '41VY921',
#  '41VZ395',
#  '41YC084',
#  '41YE478',
#  '41YF928',
#  '41YF962',
#  '41YF964',
#  '41YH367',
#  '41YH370',
#  '41YH370',
#  '41YH869',
#  '41YK214',
#  '41YK993',
#  '41YM575',
#  '41YM979',
#  '41YT117',
#  '41YT687',
#  '41YU695',
#  '41YV361',
#  '41YV361',
#  '41YV804',
#  '41YY139',
#  '41YY450',
#  '42AAP332',
#  '42AHA51',
#  '42CNU36',
#  '42DPE08',
#  '42DPE26',
#  '42EPD99',
#  '42FFM04',
#  '42HD453',
#  '42KK562',
#  '42R5076',
#  '42UM850',
#  '43AAB92',
#  '43AJ781',
#  '43EP400',
#  '43FY768',
#  '43HY781',
#  '43PE670',
#  '43SE6761',
#  '43U2715',
#  '43U2715',
#  '43VD979',
#  '55AUF82',
#  '59AG953',
#  '59MA0002',
#  '67SH055',
#  '68EZ929',
#  '70EF039',
#  '78AG824',
#  '78BN724']

# %%
df2
# Out:
#      1  2  3  4  5  6  7     8
# 0    0  1  B  H  9  0  7  None
# 1    0  1  B  H  9  0  7  None
# 2    0  1  B  H  9  0  7  None
# 3    0  1  D  E  V  2  5  None
# 4    0  1  D  H  F  8  1  None
# 5    0  1  E  J  J  7  0  None
# 6    0  3  R  H  0  1  2  None
# 7    0  4  B  Y  6  0  6     6
# 8    0  5  D  H  4  6  6  None
# 9    0  6  A  N  G  4  2  None
# 10   0  6  B  A  F  3  4  None
# 11   0  6  B  B  T  2  3  None
# 12   0  6  B  E  H  2  7  None
# 13   0  6  B  F  A  5  4  None
# 14   0  6  B  F  V  3  0  None
# 15   0  6  B  H  B  1  7  None
# 16   0  6  B  H  C  7  5  None
# 17   0  6  B  I  D  7  0  None
# 18   0  6  B  I  D  8  0  None
# 19   0  6  B  Y  6  0  6     0
# 20   0  6  B  Y  6  0  6     4
# 21   0  6  B  Y  6  0  6     6
# 22   0  6  B  Y  6  0  6     8
# 23   0  6  B  Y  6  0  7     4
# 24   0  6  D  K  5  3  0     3
# 25   0  6  D  K  5  3  0     6
# 26   0  6  D  K  5  3  0     6
# 27   0  6  D  K  5  9  0     6
# 28   0  6  D  L  7  3  2     3
# 29   0  6  E  G  2  9  9     6
# ..  .. .. .. .. .. .. ..   ...
# 361  4  1  Y  Y  4  5  0  None
# 362  4  2  A  A  P  3  3     2
# 363  4  2  A  H  A  5  1  None
# 364  4  2  C  N  U  3  6  None
# 365  4  2  D  P  E  0  8  None
# 366  4  2  D  P  E  2  6  None
# 367  4  2  E  P  D  9  9  None
# 368  4  2  F  F  M  0  4  None
# 369  4  2  H  D  4  5  3  None
# 370  4  2  K  K  5  6  2  None
# 371  4  2  R  5  0  7  6  None
# 372  4  2  U  M  8  5  0  None
# 373  4  3  A  A  B  9  2  None
# 374  4  3  A  J  7  8  1  None
# 375  4  3  E  P  4  0  0  None
# 376  4  3  F  Y  7  6  8  None
# 377  4  3  H  Y  7  8  1  None
# 378  4  3  P  E  6  7  0  None
# 379  4  3  S  E  6  7  6     1
# 380  4  3  U  2  7  1  5  None
# 381  4  3  U  2  7  1  5  None
# 382  4  3  V  D  9  7  9  None
# 383  5  5  A  U  F  8  2  None
# 384  5  9  A  G  9  5  3  None
# 385  5  9  M  A  0  0  0     2
# 386  6  7  S  H  0  5  5  None
# 387  6  8  E  Z  9  2  9  None
# 388  7  0  E  F  0  3  9  None
# 389  7  8  A  G  8  2  4  None
# 390  7  8  B  N  7  2  4  None
#
# [391 rows x 8 columns]

# %%
# full set
path=ROOT_DATA_DIR + '/4607/img'
df1= p.datacreate(path,True,'')   #2nd param path_true,3rd param takes list

# %% [markdown]
# # Full set vs predictions distribution

# %% [markdown]
# # from 1st to 1-5 th

# %%
#plot for the 1.st char of plate
p.cnt_plot(df1,'1','İlk',kac_adet,"Full")
p.cnt_plot(df2,'1','İlk',kac_adet,"Hatalı") 

#plot for firt 2 chars of plate
p.cnt_plot(df1['1'] + df1['2'],'1','İlk 2',kac_adet,"Full")
p.cnt_plot(df2['1'] + df2['2'],'1','İlk 2',kac_adet,"Hatalı") 

#plot for first 3 chars of plate
p.cnt_plot(df1['1'] + df1['2'] + df1['3'],'1','İlk 3',kac_adet,"Full")
p.cnt_plot(df2['1'] + df2['2'] + df2['3'],'1','İlk 3',kac_adet,"Hatalı") 

#plot for firt 4 chars of plate
p.cnt_plot(df1['1'] + df1['2'] + df1['3'] + df1['4'],'1','İlk 4',kac_adet,"Full")
p.cnt_plot(df2['1'] + df2['2'] + df2['3'] + df2['4'],'1','İlk 4',kac_adet,"Hatalı")
#first 5
p.cnt_plot(df1['1'] + df1['2'] + df1['3'] + df1['4'] + df1['5'],'1','İlk 5',kac_adet,"Full")
p.cnt_plot(df2['1'] + df2['2'] + df2['3'] + df2['4'] + df2['5'],'1','İlk 5',kac_adet,"Hatalı")

# %% [markdown]
# # from 2nd char to 5 th

# %%
#plot for the 2nd char of plate
p.cnt_plot(df1['2'],'2','2.char',kac_adet,"Full")
p.cnt_plot(df2['2'],'2','2.char',kac_adet,"Hatalı")

#plot for 2+3 chars of plate
p.cnt_plot(df1['2'],'2','İlk 2',kac_adet,"Full")
p.cnt_plot(df2['2'],'2','İlk 2',kac_adet,"Hatalı") 

#plot for 2,3,4 chars of plate
p.cnt_plot(df1['2'] + df1['3'],'2','2-3',kac_adet,"Full")
p.cnt_plot(df2['2'] + df2['3'],'2','2-3',kac_adet,"Hatalı") 

#plot for firt 4 chars of plate
p.cnt_plot(df1['2'] + df1['3'] + df1['4'],'2','2-4',kac_adet,"Full")
p.cnt_plot(df2['2'] + df2['3'] + df2['4'],'2','2-4',kac_adet,"Hatalı")
#first 5
p.cnt_plot(df1['2'] + df1['3'] + df1['4'] + df1['5'],'2','2-5',kac_adet,"Full")
p.cnt_plot(df2['2'] + df2['3'] + df2['4'] + df2['5'],'2','2-5',kac_adet,"Hatalı")

# %%
100- nmatched/(nmatched+matched)*100

# %%
nmatch_str
